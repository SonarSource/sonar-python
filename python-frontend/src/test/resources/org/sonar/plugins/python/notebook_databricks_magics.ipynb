# %%
shared = 41

# %%
# %sql SELECT count(*)
FROM events
WHERE active = true

# %%
# %run ../core/utils

# %%
# %run
../core/init

# %%
# %sql
SELECT 1
FROM values

# %%
# %time shared + 1
result = shared + 1

# %%
answer = shared + 1
print answer
