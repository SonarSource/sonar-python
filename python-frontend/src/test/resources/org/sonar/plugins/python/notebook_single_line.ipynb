# %%
# Code you have previously used to load data
import pandas as pd

t = '../input/home-data-for-ml-course/train.csv'

# %%
""" A docstring that is going to be multiline
Here is the second line !
"""
