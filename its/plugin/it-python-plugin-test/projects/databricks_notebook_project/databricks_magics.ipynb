# %%
before = f'before'

# %%
# %sql
-- A customer's [ note
SELECT 1 AS value

# %%
# %run
./team's [ setup

# %%
# %%sql
# -- Another customer's ( note
# SELECT 2 AS value

# %%
# %time before
after = f'after'
